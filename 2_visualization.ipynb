# %% [markdown]
# ## 2 : Exploratory Visualization
#
# ### Character width and height

# %% [markdown]
# First reload the data we generated in 1_download.ipynb.

# %%
# These are all the modules I'll be using later. 
from __future__ import print_function
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import tarfile
from IPython.display import display, Image
from scipy import ndimage
from sklearn.linear_model import LogisticRegression
from six.moves.urllib.request import urlretrieve
from six.moves import cPickle as pickle

import pandas as pd
import urllib
import cPickle as pickle
from PIL import Image
import scipy.io as sio
import scipy.io
import h5py
import random
import tensorflow as tf
from sklearn.cross_validation import train_test_split as ttsplit
import math as math
import pylab as P
# %matplotlib inline

# %%
def open_pickle(folder, force=False):
  set_filename = folder + '.pickle'
  if os.path.exists(set_filename) and not force:
    with open(set_filename, 'rb') as f:
      dataset = pickle.load(f)
      return dataset
  else:
    
    print ('Unable to open data to', set_filename, '.')
    
train_data = open_pickle('train')
test_data = open_pickle('test')
extra_data = open_pickle('extra')

train_folders = 'train'
test_folders = 'test'
extra_folders = 'extra'

# %% [markdown]
# ---

# %% [markdown]
# ### train dataset

# %%
train_imgsize = np.ndarray([len(train_data),2])
for i in np.arange(len(train_data)):
    filename = os.path.join(train_folders, train_data[i]['filename'])
    img = Image.open(filename)
    train_imgsize[i, :] = img.size[:]

train_width = train_imgsize[:,0]
train_height = train_imgsize[:,1]
train_dims = pd.DataFrame({ 'width': train_width, 'height': train_height })

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,4))
    
ax1.hist(train_width, range=[0, 1200], facecolor='#2E3192')
ax1.set_title('Bounding box width')
ax1.set_xlabel('Pixels')
ax1.set_ylabel('Number of samples')

ax2.hist(train_height, range=[0, 600], facecolor='#FFDA44')
ax2.set_title('Bounding box height')
ax2.set_xlabel('Pixels')
ax2.set_ylabel('Number of sumples')

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### test dataset

# %%
test_imgsize = np.ndarray([len(test_data),2])
for i in np.arange(len(test_data)):
    filename = os.path.join(test_folders, test_data[i]['filename'])
    img = Image.open(filename)
    test_imgsize[i, :] = img.size[:]

test_width = test_imgsize[:,0]
test_height = test_imgsize[:,1]
test_dims = pd.DataFrame({ 'width': test_width, 'height': test_height })

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,4))
    
ax1.hist(test_width, range=[0, 1200], facecolor='#2E3192')
ax1.set_title('Bounding box width')
ax1.set_xlabel('Pixels')
ax1.set_ylabel('Number of samples')

ax2.hist(test_height, range=[0, 600], facecolor='#FFDA44')
ax2.set_title('Bounding box height')
ax2.set_xlabel('Pixels')
ax2.set_ylabel('Number of sumples')

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### extra dataset

# %%
extra_imgsize = np.ndarray([len(extra_data),2])
for i in np.arange(len(extra_data)):
    filename = os.path.join(extra_folders, extra_data[i]['filename'])
    img = Image.open(filename)
    extra_imgsize[i, :] = img.size[:]

extra_width = extra_imgsize[:,0]
extra_height = extra_imgsize[:,1]
extra_dims = pd.DataFrame({ 'width': extra_width, 'height': extra_height })

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,4))
    
ax1.hist(extra_width, range=[0, 900], facecolor='#2E3192')
ax1.set_title('Bounding box width')
ax1.set_xlabel('Pixels')
ax1.set_ylabel('Number of samples')

ax2.hist(extra_height, range=[0, 500], facecolor='#FFDA44')
ax2.set_title('Bounding box height')
ax2.set_xlabel('Pixels')
ax2.set_ylabel('Number of sumples')

plt.show()
